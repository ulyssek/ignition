# %%
#################################################################################################
## Import Section & Session creation

from multiple_sessions import *
import matplotlib.pyplot as plt 
import numpy as np

import seaborn as sns

import plotly.plotly as py 
import plotly.graph_objs as go   
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import pandas as pd

sd = MultipleSessions("dlPFC",normalized=,excluded=["dlPFC_SESSION_E20150331_4.mat"])
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
for sss in sd.sessions:
    print(sss.file_name)
    sss.plot_figure_1("seen",ao_trials=True,ao_channels=True,ao_contrast=True)
# Out:
# dlPFC_SESSION_E20150401_5.mat
# /usr/local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:2920: RuntimeWarning:
#
# Mean of empty slice.
#
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning:
#
# invalid value encountered in true_divide
# dlPFC_SESSION_E20150219_9.mat
# dlPFC_SESSION_E20150311_4.mat
# dlPFC_SESSION_E20150319_8.mat
# dlPFC_SESSION_E20150330_5.mat
# dlPFC_SESSION_E20150312_3.mat
# dlPFC_SESSION_E20150309_3.mat
# dlPFC_SESSION_E20150305_3.mat
# dlPFC_SESSION_E20150225_2.mat
# dlPFC_SESSION_E20150226_18.mat
# dlPFC_SESSION_E20150323_3.mat
# dlPFC_SESSION_E20150305_5.mat
# dlPFC_SESSION_E20150325_2.mat
# dlPFC_SESSION_E20150224_3.mat
# dlPFC_SESSION_E20150304_5.mat
