# %%
#################################################################################################
## Import Section & Session creation

from multiple_sessions import *
import matplotlib.pyplot as plt 
import numpy as np

import seaborn as sns

import plotly.plotly as py 
import plotly.graph_objs as go   
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)

import pandas as pd

s = MultipleSessions("V1",normalized=True)
s4 = MultipleSessions("V4",normalized=True)
sd = MultipleSessions("dlPFC",normalized=False,excluded=["dlPFC_SESSION_E20150331_4.mat"])
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>
# ...

# %%
#################################################################################################
#Seen - Missed
d1 = s.plot_figure_1("seen",ao_channels=True,ao_trials=True,ao_contrast=True,low_contrast=True,medium_contrast=True,high_contrast=True,smooth=1,show=True)
d2 = s.plot_figure_1("missed",ao_channels=True,ao_trials=True,ao_contrast=True,low_contrast=True,medium_contrast=True,high_contrast=True,smooth=1,show=True)

s._core_figure_1(d1-d2,title="Seen - Missed",smooth=1,show=False)
plt.show()
